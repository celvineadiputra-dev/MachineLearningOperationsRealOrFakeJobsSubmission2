# %%
import os

from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner
from modules import components, pipeline_orchestrator

# %%
DATA_ROOT = "dataset"
OUTPUT_BASE = "celvine-pipelines"

PIPELINE_NAME = "real-or-fake-jobs-detection-pipeline"

TRANSFORM_MODULE_FILE_PATH = "modules/real_or_fake_job_transform.py"
TRAINER_MODULE_FILE_PATH = "modules/real_or_fake_job_trainer.py"
TUNER_MODULE_FILE_PATH = "modules/real_or_fake_job_tuner.py"

SERVING_DIRECTORY = "serving_model_dir/real-or-fake-jobs-detection-model"

PIPELINE_ROOT = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
METADATA_PATH = os.path.join(PIPELINE_ROOT, "metadata.sqlite")

# %%
component_agrs = {
    "data_root": DATA_ROOT,
    "transform_module_file_path": TRANSFORM_MODULE_FILE_PATH,
    "trainer_module_file_path": TRAINER_MODULE_FILE_PATH,
    "tuner_module_file_path": TUNER_MODULE_FILE_PATH,
    "serving_directory": SERVING_DIRECTORY
}

# %%
main_components = components.init_components(component_agrs)

# %%
pipline = pipeline_orchestrator.init_pipeline_orchestrator(
    main_components,
    PIPELINE_ROOT,
    PIPELINE_NAME,
    METADATA_PATH,
)

BeamDagRunner().run(pipline)
# Out:
# Trial 10 Complete [00h 03m 32s]
# binary_accuracy: 0.9573717713356018
#
# Best binary_accuracy So Far: 0.9993589520454407
# Total elapsed time: 00h 21m 41s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# ERROR:absl:Execution 7 failed.
# Results summary
# Results in celvine-pipelines\real-or-fake-jobs-detection-pipeline\Tuner\.system\executor_execution\7\.temp\7\kt_hyperband
# Showing 10 best trials
# Objective(name="binary_accuracy", direction="max")
#
# Trial 0005 summary
# Hyperparameters:
# num_hidden_layers: 2
# embed_dims: 112
# lstm_units: 64
# dense_units: 256
# dropout_rate: 0.2
# learning_rate: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0004
# Score: 0.9993589520454407
#
# Trial 0006 summary
# Hyperparameters:
# num_hidden_layers: 2
# embed_dims: 16
# lstm_units: 128
# dense_units: 64
# dropout_rate: 0.2
# learning_rate: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0000
# Score: 0.9919871687889099
#
# Trial 0009 summary
# Hyperparameters:
# num_hidden_layers: 2
# embed_dims: 48
# lstm_units: 128
# dense_units: 224
# dropout_rate: 0.1
# learning_rate: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.9573717713356018
#
# Trial 0004 summary
# Hyperparameters:
# num_hidden_layers: 2
# embed_dims: 112
# lstm_units: 64
# dense_units: 256
# dropout_rate: 0.2
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9474359154701233
#
# Trial 0000 summary
# Hyperparameters:
# num_hidden_layers: 2
# embed_dims: 16
# lstm_units: 128
# dense_units: 64
# dropout_rate: 0.2
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9163461327552795
#
# Trial 0002 summary
# Hyperparameters:
# num_hidden_layers: 1
# embed_dims: 80
# lstm_units: 96
# dense_units: 32
# dropout_rate: 0.2
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.9150640964508057
#
# Trial 0008 summary
# Hyperparameters:
# num_hidden_layers: 1
# embed_dims: 80
# lstm_units: 32
# dense_units: 128
# dropout_rate: 0.1
# learning_rate: 0.0001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.910897433757782
#
# Trial 0007 summary
# Hyperparameters:
# num_hidden_layers: 1
# embed_dims: 16
# lstm_units: 96
# dense_units: 128
# dropout_rate: 0.5
# learning_rate: 0.001
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.903205156326294
#
# Trial 0001 summary
# Hyperparameters:
# num_hidden_layers: 1
# embed_dims: 80
# lstm_units: 96
# dense_units: 160
# dropout_rate: 0.4
# learning_rate: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.8980769515037537
#
# Trial 0003 summary
# Hyperparameters:
# num_hidden_layers: 2
# embed_dims: 80
# lstm_units: 96
# dense_units: 224
# dropout_rate: 0.4
# learning_rate: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.870192289352417
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\components\tuner\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     123
# --> 124     write_best_hyperparameters(tuner, output_dict)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\components\tuner\executor.py in write_best_hyperparameters(tuner, output_dict)
#      74   results = []
# ---> 75   for trial_obj in tuner.oracle.get_best_trials(tuner.oracle.max_trials):
#      76     if trial_obj.status == trial.TrialStatus.COMPLETED and trial_obj.hyperparameters.values:
#
# ~\anaconda3\envs\sub2\lib\site-packages\keras_tuner\engine\oracle.py in get_best_trials(self, num_trials)
#     513
# --> 514         if len(sorted_trials) < num_trials:
#     515             sorted_trials = sorted_trials + [
#
# TypeError: '<' not supported between instances of 'int' and 'NoneType'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1368\1585421913.py in <cell line: 8>()
#       6 )
#       7
# ----> 8 BeamDagRunner().run(pipline)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\tfx_runner.py in run(self, pipeline, run_options, **kwargs)
#     122     else:
#     123       run_options_pb = None
# --> 124     return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in run_with_ir(self, pipeline, run_options)
#     295                       pipeline=pipeline),
#     296                   *[beam.pvalue.AsIter(s) for s in signals_to_wait]))
# --> 297           logging.info('Node %s is scheduled.', node_id)
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     598     try:
#     599       if not exc_type:
# --> 600         self.result = self.run()
#     601         self.result.wait_until_finish()
#     602     finally:
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\pipeline.py in run(self, test_runner_api)
#     575         finally:
#     576           shutil.rmtree(tmpdir)
# --> 577       return self.runner.run_pipeline(self, self._options)
#     578     finally:
#     579       if not is_in_ipython():
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\direct\direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_pipeline(self, pipeline, options)
#     200         options.view_as(pipeline_options.ProfilingOptions))
#     201
# --> 202     self._latest_run_result = self.run_via_runner_api(
#     203         pipeline.to_runner_api(default_environment=self._default_environment),
#     204         options)
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_via_runner_api(self, pipeline_proto, options)
#     222       pipeline_proto = self.embed_default_docker_image(pipeline_proto)
#     223     stage_context, stages = self.create_stages(pipeline_proto)
# --> 224     return self.run_stages(stage_context, stages)
#     225
#     226   def embed_default_docker_image(self, pipeline_proto):
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_stages(self, stage_context, stages)
#     453
#     454           bundle_counter += 1
# --> 455           bundle_results = self._execute_bundle(
#     456               runner_execution_context, bundle_context_manager, bundle_input)
#     457
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _execute_bundle(self, runner_execution_context, bundle_context_manager, bundle_input)
#     781
#     782     last_result, deferred_inputs, newly_set_timers, watermark_updates = (
# --> 783         self._run_bundle(
#     784             runner_execution_context,
#     785             bundle_context_manager,
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, bundle_input, data_output, expected_timer_output, bundle_manager)
#    1010         expected_timer_output)
#    1011
# -> 1012     result, splits = bundle_manager.process_bundle(
#    1013         data_input, data_output, input_timers, expected_timer_output)
#    1014     # Now we collect all the deferred inputs remaining from bundle execution.
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1346             process_bundle_descriptor.id,
#    1347             cache_tokens=[next(self._cache_token_generator)]))
# -> 1348     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1349
#    1350     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py in push(self, request)
#     377       self._uid_counter += 1
#     378       request.instruction_id = 'control_%s' % self._uid_counter
# --> 379     response = self.worker.do_instruction(request)
#     380     return ControlFuture(request.instruction_id, response)
#     381
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in do_instruction(self, request)
#     622     if request_type:
#     623       # E.g. if register is set, this will call self.register(request.register))
# --> 624       return getattr(self, request_type)(
#     625           getattr(request, request_type), request.instruction_id)
#     626     else:
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in process_bundle(self, request, instruction_id)
#     660         with self.maybe_profile(instruction_id):
#     661           delayed_applications, requests_finalization = (
# --> 662               bundle_processor.process_bundle(instruction_id))
#     663           monitoring_infos = bundle_processor.monitoring_infos()
#     664           response = beam_fn_api_pb2.InstructionResponse(
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_bundle(self, instruction_id)
#    1060                   element.timer_family_id, timer_data)
#    1061           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
# -> 1062             input_op_by_transform_id[element.transform_id].process_encoded(
#    1063                 element.data)
#    1064
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     230       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     231           input_stream, True)
# --> 232       self.output(decoded_value)
#     233
#     234   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~\anaconda3\envs\sub2\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      88
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#      92
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      97       with metadata.Metadata(self._mlmd_connection_config) as mlmd_handle:
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#     101         mlmd_connection=metadata.Metadata(self._mlmd_connection_config),
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     571               executor_watcher.address)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#     575         execution_output = (
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     446     outputs_utils.make_output_dirs(execution_info.output_dict)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#     450       if code != 0:
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     133         pipeline_run_id=execution_info.pipeline_run_id)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      56
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#      60   if not result:
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\components\tuner\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     122     tuner = search(input_dict, exec_properties, self._get_tmp_dir())
#     123
# --> 124     write_best_hyperparameters(tuner, output_dict)
#
# ~\anaconda3\envs\sub2\lib\site-packages\tfx\components\tuner\executor.py in write_best_hyperparameters(tuner, output_dict)
#      73   # Saves tuner results in pandas `records` format (list of rows).
#      74   results = []
# ---> 75   for trial_obj in tuner.oracle.get_best_trials(tuner.oracle.max_trials):
#      76     if trial_obj.status == trial.TrialStatus.COMPLETED and trial_obj.hyperparameters.values:
#      77       results.append({
#
# ~\anaconda3\envs\sub2\lib\site-packages\keras_tuner\engine\oracle.py in get_best_trials(self, num_trials)
#     512         )
#     513
# --> 514         if len(sorted_trials) < num_trials:
#     515             sorted_trials = sorted_trials + [
#     516                 t
#
# TypeError: '<' not supported between instances of 'int' and 'NoneType' [while running 'Run[Tuner]']
